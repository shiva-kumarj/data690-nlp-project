# %%
import pandas as pd

# %%
#get east-coast data
df_wp = pd.read_csv('news/east-coast/dc/articles.csv')
df_md = pd.read_csv('news/east-coast/md/articles.csv')
df_nyt = pd.read_csv('news/east-coast/nyc/articles.csv')
#get west-coast data
df_la = pd.read_csv('news/west-coast/la/articles.csv')
df_sf = pd.read_csv('news/west-coast/sf/articles.csv')
df_ws = pd.read_csv('news/west-coast/ws/articles.csv')
#get mid-west data
df_cst = pd.read_csv('news/mid-west/chicago/articles.csv')
df_mst = pd.read_csv('news/mid-west/minneapolis/articles.csv')
df_dn = pd.read_csv('news/mid-west/dallas/articles.csv')
df_hc = pd.read_csv('news/mid-west/houston/articles.csv')

# %% [markdown]
# #### will compare the sentiment of the three regions

# %%
west_coast_df = pd.concat([df_la, df_sf, df_ws], axis=0).reset_index(drop = True)
east_coast_df = pd.concat([df_wp, df_md, df_nyt], axis=0).reset_index(drop = True)
mid_west_df = pd.concat([df_cst, df_mst, df_dn, df_hc], axis=0).reset_index(drop = True)

# %%
west_coast_df
# Out:
#                                                 title  \
# 0    Commentary: Driving an EV does not make you p...
# 1    Op-Ed: Think bigger. Switching to electric ca...
# 2    Editorial: EPA wants to speed up EV switch. G...
# 3    California’s electric car revolution, designe...
# 4    Electric cars now make up a fifth of Californ...
# 5    Column: Can Los Angeles lead the world on cli...
# 6   Environmental groups want SF to nudge Uber, Ly...
# 7   To cut carbon footprint, SF moves to eliminate...
# 8   With new grant program, Bay Area spreads elect...
# 9   Berkeley considers banning the sale of gas-pow...
# 10  Letters: Fight climate change and ease into fu...
# 11  How electric cars can keep California’s power ...
# 12  Cities awarded funding for electric vehicle ch...
# 13  Adapt or mitigate? Washington Republicans roll...
# 14  Op-ed: Now is the Time to Electrify Public Veh...
# 15  Washington State passes law establishing 2030 ...
# 16  Electric Vehicle Tax Break Extension Faces Sti...
# 17  Cities awarded funding for electric vehicle ch...
#
#                                               article  \
# 0   ['When I started driving an electric vehicle i...
# 1   ['It might feel like the easy solution — just ...
# 2   ['The Biden administration just proposed hitti...
# 3   ['The precious cargo on the ship docked in San...
# 4   ['One out of every 5 cars sold in California i...
# 5   ['When the eyes of the world turn to Los Angel...
# 6   Environmental advocates want San Francisco to ...
# 7   San Francisco officials want to shrink the cit...
# 8   This is a carousel. Use Next and Previous butt...
# 9   This is a carousel. Use Next and Previous butt...
# 10  Mandating more hybrid cars, such as the 2020 T...
# 11  When we’re not driving them, electric cars, tr...
# 12  The Washington State Department of Commerce (C...
# 13  A new proposal from Washington State Republica...
# 14  Matthew Metz is the founder and co-executive d...
# 15  The Washington State legislature has passed gr...
# 16  Consider the political oddity that is the elec...
# 17  The Washington State Department of Commerce (C...
#
#                                       date          news_source      region
# 0               Sept. 17, 2022 3:10 AM PT               latimes  west-coast
# 1                  Sept. 15, 2022 3 AM PT               latimes  west-coast
# 2               April 12, 2023 3:57 PM PT               latimes  west-coast
# 3                   July 21, 2021 3 AM PT               latimes  west-coast
# 4                 Nov. 1, 2023 2:46 PM PT               latimes  west-coast
# 5                   Oct. 26, 2023 6 AM PT               latimes  west-coast
# 6   \n            March 21, 2019\n                  sfchronicle  west-coast
# 7    \n            July 16, 2019\n                  sfchronicle  west-coast
# 8                             Dec. 7, 2019          sfchronicle  west-coast
# 9                            Jan. 11, 2021          sfchronicle  west-coast
# 10                           Sep. 14, 2022          sfchronicle  west-coast
# 11                           July 28, 2022          sfchronicle  west-coast
# 12                       December 28, 2020  washingtonstatewire  west-coast
# 13                       November 30, 2021  washingtonstatewire  west-coast
# 14                            June 5, 2018  washingtonstatewire  west-coast
# 15                          April 15, 2021  washingtonstatewire  west-coast
# 16                        January 21, 2015  washingtonstatewire  west-coast
# 17                       December 28, 2020  washingtonstatewire  west-coast

# %%
east_coast_df
# Out:
#                                                 title  \
# 0   Are electric cars really better for the enviro...
# 1   Electric Vehicles Alone Can’t Solve Climate Ch...
# 2   Even electric self-driving cars may have a cli...
# 3   Most electric vehicles won’t qualify for feder...
# 4   Dan Rodricks: All charged up for an electric c...
# 5   Rivian electric car plant blasted by foes at G...
# 6   Hogan administration won’t match California’s ...
# 7   California electric vehicle rule takes another...
# 8                    How Green Are Electric Vehicles?
# 9   Electric Cars Are Better for the Planet – and ...
# 10  How Electrifying Everything Became a Key Clima...
# 11  Electric Cars Too Costly for Many, Even With A...
#
#                                               article  \
# 0   Electric vehicles, you might have heard, have ...
# 1   Arresting climate change requires, among other...
# 2   The future energy required to run just the com...
# 3   DETROIT — A tax credit of up to $7,500 could b...
# 4   If you own an electric car or truck, or drive ...
# 5   MONROE, Ga. — Opponents trying to derail a $5 ...
# 6   Maryland Gov. Larry Hogan’s administration won...
# 7   Maryland took a big step Monday toward eventua...
# 8   Advertisement Supported by In short: Very gree...
# 9   Advertisement ByVeronica PenneyJan. 15, 2021 E...
# 10  Advertisement ByNadja PopovichandBrad PlumerAp...
# 11  Advertisement Supported by Battery-powered veh...
#
#                                             date      news_source      region
# 0            September 19, 2023 at 6:30 a.m. EDT  washington-post  east-coast
# 1                  May 17, 2023 at 8:04 a.m. EDT  washington-post  east-coast
# 2              January 13, 2023 at 1:43 p.m. EST  washington-post  east-coast
# 3                            2022-08-09 10:54:00     baltimoresun  east-coast
# 4                            2022-08-16 11:12:00     baltimoresun  east-coast
# 5                            2022-04-20 12:13:00     baltimoresun  east-coast
# 6                            2022-12-14 15:59:00     baltimoresun  east-coast
# 7                            2023-03-13 17:52:00     baltimoresun  east-coast
# 8   Published March 2, 2021Updated June 23, 2023   new-york-times  east-coast
# 9                                  Jan. 15, 2021   new-york-times  east-coast
# 10                                April 14, 2023   new-york-times  east-coast
# 11    Published Aug. 8, 2022Updated Aug. 9, 2022   new-york-times  east-coast

# %%
mid_west_df
# Out:
#                                                 title  \
# 0   Electric vehicle charging stations could be bo...
# 1   Pritzker signs electric vehicle legislation, a...
# 2   Illinois is sitting on millions that could be ...
# 3   Bring electric vehicle manufacturing to Illino...
# 4     Ford to bring out 40 electrics, hybrids by 2022
# 5                   EVs are only part of the solution
# 6   Energy secretary announces electric vehicle gr...
# 7   This farm reporter roams rural Minnesota by EV...
# 8   Minnesota auto dealers lose court fight with s...
# 9   2023 tax credits may boost the appeal of elect...
# 10  Are electric vehicles the future? Here’s what ...
# 11  Only 10 electric vehicles will qualify for $7,...
# 12  New Texas laws aimed at sharp rise in electric...
# 13  How electric vehicles can help cities like Hou...
# 14    Opinion: Electric vehicles are no silver bullet
# 15  Nearly half of U.S. car buyers plan to go elec...
#
#                                               article  \
# 0   \nI have owned and driven an electric vehicle ...
# 1   \nGov. J.B. Pritzker on Tuesday signed legisla...
# 2   \nIllinois has an electric vehicle chicken-and...
# 3   \nAs some corporate headquarters decamp for ot...
# 4   \nDETROIT — Ford Motor Co. said it’s doubling ...
# 5   Arresting climate change requires, among other...
# 6   Two Minnesota organizations, including a Nativ...
# 7   The first time I knew our new Nissan Leaf was ...
# 8   The Minnesota Court of Appeals has upheld the ...
# 9   businessAutos ByThe Associated Press 5:38 AM o...
# 10  News ByNoor Adatia 8:00 AM on Oct 8, 2022 CDT ...
# 11  businessAutos ByThe Associated Press 1:38 PM o...
# 12  newsPolitics ByAarón Torres 6:00 AM on Jul 3, ...
# 13  Houston Mayor Sylvester Turner was one ofmore ...
# 14  Regarding "Tomlinson: GM’s new Hummer and othe...
# 15  Analysts at Ernst and Young surveyed 1,500 U.S...
#
#                            date               news_source    region
# 0           2021-04-05 12:30:27          chicago-suntimes  mid-west
# 1           2021-11-16 12:03:13          chicago-suntimes  mid-west
# 2           2021-04-04 15:52:24          chicago-suntimes  mid-west
# 3           2023-07-17 07:00:00          chicago-suntimes  mid-west
# 4           2018-01-14 18:39:00          chicago-suntimes  mid-west
# 5         May 21, 2023 — 6:00pm  minneapolis-star-tribune  mid-west
# 6         May 19, 2023 — 6:57pm  minneapolis-star-tribune  mid-west
# 7     October 14, 2023 — 1:45pm  minneapolis-star-tribune  mid-west
# 8     January 30, 2023 — 6:18pm  minneapolis-star-tribune  mid-west
# 9   5:38 AM on Dec 28, 2022 CST                dallasnews  mid-west
# 10   8:00 AM on Oct 8, 2022 CDT                dallasnews  mid-west
# 11  1:38 PM on Apr 17, 2023 CDT                dallasnews  mid-west
# 12   6:00 AM on Jul 3, 2023 CDT                dallasnews  mid-west
# 13                June 15, 2017          houstonchronicle  mid-west
# 14                Jan. 20, 2023          houstonchronicle  mid-west
# 15                 July 3, 2023          houstonchronicle  mid-west
